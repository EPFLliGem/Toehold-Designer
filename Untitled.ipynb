# %%
from bs4 import BeautifulSoup
import requests as rq

url='http://www.nupack.org/partition/new'

# %%
page = rq.get(url)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
form = soup.find('form',  id="partition_job")
inp = form.find_all('input')
sel = form.find_all('select')
area = form.find_all('textarea')
for a in area: 
    print(a)
# Out:
# <textarea class="sequence_editor" cols="60" id="partition_sequence_0_contents" name="partition_sequence[0][contents]" rows="5"></textarea>
# <textarea class="sequence_editor" cols="60" id="partition_job_predefined_complexes" name="partition_job[predefined_complexes]" rows="10"></textarea>

# %%
form.find('input', id="mfe_sequence")

# %%
post.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="shortcut icon" href="/images/nupack_favicon.png" type="image/x-icon" />\n<meta name="keywords"\n      content="RNA, DNA, base pairing, secondary structure, folding, thermodynamics, \n               design, prediction, minimum free energy, MFE, equilibrium, nucleic acids, \n               mRNA, primer, interacting, strands, oligonucleotide, oligo, exact, \n               partition function, pseudoknot, unpseudoknotted, polynomial time, \n               algorithm, drawing, target, pair probabilities, utilities">\n<meta charset="utf-8" />\n<title>NUPACK: Utilities</title>\n<link href="/stylesheets/screen.css?1451934198" media="screen" rel="Stylesheet" type="text/css" />\n<link href="/stylesheets/nupack_main.css?1452120087" media="screen" rel="Stylesheet" type="text/css" />\n\n<link href="/stylesheets/slider.css?1415077223" media="screen" rel="Stylesheet" type="text/css" />\n<link href="/stylesheets/screen_form.css?1415077223" media="screen" r
# ...
